# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,StratifiedKFold
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.metrics import f1_score
from sklearn.preprocessing import LabelEncoder, TargetEncoder
import lightgbm as lgb
import category_encoders as ce
import re

# pandasの行を省略しない
pd.set_option('display.max_columns', None)

# %%
train_df = pd.read_csv('C:/python/signate/data/train.csv', index_col=0)
test_df = pd.read_csv('C:/python/signate/data/test.csv', index_col=0)
sample_df = pd.read_csv('C:/python/signate/data/sample_submission.csv', header=None, index_col=0)

# %%
# train_dfのcolumnを取得
columns = test_df.columns

# %%
def cleansing(df):
    df['created_at'] = pd.to_datetime(df['created_at'])
    df['year'] = df['created_at'].dt.year
    df['month'] = df['created_at'].dt.month
    df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
    df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)
    df.drop('created_at', axis=1, inplace=True)
    df['steward'].fillna('0', inplace=True)
    df['guards'].fillna('0', inplace=True)
    df['problems'].fillna('NoProblem', inplace=True)

    df['spc_genus'] = df['spc_latin'].str.split(' ').str[0]
    df.drop('spc_latin', axis=1, inplace=True)
    return df

train_clean = cleansing(train_df)
test_clean = cleansing(test_df)

# %%
# 一旦lightgbmで学習してみる
# target encodingとラベル削除を行う

# 使わないcolumnを指定
drop_col = []
# カテゴリカル変数を指定
te_columns = ['guards', 'sidewalk']

# カテゴリカルカラムから使わないcolumnを削除
te_columns = list(set(te_columns) - set(drop_col))

for i in range(3):
    train_clean['onehot' + str(i)] = 0
    train_clean['onehot' + str(i)] = train_clean['onehot' + str(i)].mask(train_clean['health'] == i, 1)

te_columns_list = []

for te_column in te_columns:
    tmp_list = []
    for i in range(3):
        train_clean[te_column + '-te' + str(i)] = train_clean[te_column]
        test_clean[te_column + '-te' + str(i)] = test_clean[te_column]
        tmp_list.append(te_column + '-te' + str(i))
    te_columns_list.append(tmp_list)
    train_clean.drop(te_column, axis=1, inplace=True)
    test_clean.drop(te_column, axis=1, inplace=True)

print(te_columns_list)
te_columns_list = np.array(te_columns_list)

test_clean.head()
# Out:
# [['sidewalk-te0', 'sidewalk-te1', 'sidewalk-te2'], ['guards-te0', 'guards-te1', 'guards-te2']]
#        tree_dbh curb_loc steward         user_type   problems  \
# 19984        15   OnCurb       0   NYC Parks Staff  NoProblem
# 19985         5   OnCurb    1or2         Volunteer  NoProblem
# 19986         4   OnCurb       0         Volunteer  NoProblem
# 19987         7   OnCurb       0  TreesCount Staff  NoProblem
# 19988         6   OnCurb    1or2  TreesCount Staff     Stones
#
#               spc_common   nta  \
# 19984       Callery pear  BK17
# 19985             cherry  BX62
# 19986  littleleaf linden  QN60
# 19987       dawn redwood  BK09
# 19988   purple-leaf plum  BK75
#
#                                              nta_name  borocode  boro_ct  \
# 19984  Sheepshead Bay-Gerritsen Beach-Manhattan Beach         3  3062000
# 19985                              Woodlawn-Wakefield         2  2045101
# 19986                                     Kew Gardens         4  4013800
# 19987                    Brooklyn Heights-Cobble Hill         3  3000301
# 19988                                         Bedford         3  3025100
#
#        boroname     zip_city  cb_num  st_senate  st_assem  cncldist  year  \
# 19984  Brooklyn     Brooklyn     315         22        45        48  2015
# 19985     Bronx        Bronx     212         34        81        11  2015
# 19986    Queens  Kew Gardens     409         14        27        29  2016
# 19987  Brooklyn     Brooklyn     302         26        52        33  2015
# 19988  Brooklyn     Brooklyn     303         25        56        36  2015
#
#        month  month_sin     month_cos    spc_genus sidewalk-te0 sidewalk-te1  \
# 19984      9  -1.000000 -1.836970e-16        Pyrus       Damage       Damage
# 19985     10  -0.866025  5.000000e-01       Prunus     NoDamage     NoDamage
# 19986      8  -0.866025 -5.000000e-01        Tilia     NoDamage     NoDamage
# 19987      8  -0.866025 -5.000000e-01  Metasequoia     NoDamage     NoDamage
# 19988     10  -0.866025  5.000000e-01       Prunus     NoDamage     NoDamage
#
#       sidewalk-te2 guards-te0 guards-te1 guards-te2
# 19984       Damage          0          0          0
# 19985     NoDamage          0          0          0
# 19986     NoDamage     Unsure     Unsure     Unsure
# 19987     NoDamage          0          0          0
# 19988     NoDamage    Helpful    Helpful    Helpful

# %%
for i in range(3):
    te_target = te_columns_list[:, i]
    target_enc = TargetEncoder(target_type='auto', random_state=42)
    
    train_clean[te_target] = target_enc.fit_transform(train_clean[te_target], train_clean['onehot' + str(i)])
    # テストデータにtransform
    test_clean[te_target]  = target_enc.transform(test_clean[te_target])
test_clean.head()
# Out:
#        tree_dbh curb_loc steward         user_type   problems  \
# 19984        15   OnCurb       0   NYC Parks Staff  NoProblem
# 19985         5   OnCurb    1or2         Volunteer  NoProblem
# 19986         4   OnCurb       0         Volunteer  NoProblem
# 19987         7   OnCurb       0  TreesCount Staff  NoProblem
# 19988         6   OnCurb    1or2  TreesCount Staff     Stones
#
#               spc_common   nta  \
# 19984       Callery pear  BK17
# 19985             cherry  BX62
# 19986  littleleaf linden  QN60
# 19987       dawn redwood  BK09
# 19988   purple-leaf plum  BK75
#
#                                              nta_name  borocode  boro_ct  \
# 19984  Sheepshead Bay-Gerritsen Beach-Manhattan Beach         3  3062000
# 19985                              Woodlawn-Wakefield         2  2045101
# 19986                                     Kew Gardens         4  4013800
# 19987                    Brooklyn Heights-Cobble Hill         3  3000301
# 19988                                         Bedford         3  3025100
#
#        boroname     zip_city  cb_num  st_senate  st_assem  cncldist  year  \
# 19984  Brooklyn     Brooklyn     315         22        45        48  2015
# 19985     Bronx        Bronx     212         34        81        11  2015
# 19986    Queens  Kew Gardens     409         14        27        29  2016
# 19987  Brooklyn     Brooklyn     302         26        52        33  2015
# 19988  Brooklyn     Brooklyn     303         25        56        36  2015
#
#        month  month_sin     month_cos    spc_genus  sidewalk-te0  \
# 19984      9  -1.000000 -1.836970e-16        Pyrus      0.176892
# 19985     10  -0.866025  5.000000e-01       Prunus      0.176892
# 19986      8  -0.866025 -5.000000e-01        Tilia      0.176892
# 19987      8  -0.866025 -5.000000e-01  Metasequoia      0.176892
# 19988     10  -0.866025  5.000000e-01       Prunus      0.176892
#
#        sidewalk-te1  sidewalk-te2  guards-te0  guards-te1  guards-te2
# 19984      0.788181      0.034928    0.176892    0.788181    0.034928
# 19985      0.788181      0.034928    0.176892    0.788181    0.034928
# 19986      0.788181      0.034928    0.176892    0.788181    0.034928
# 19987      0.788181      0.034928    0.176892    0.788181    0.034928
# 19988      0.788181      0.034928    0.176892    0.788181    0.034928

# %%
train_clean.head()
# Out:
#    tree_dbh curb_loc  health steward        user_type            problems  \
# 0        14   OnCurb       1       0        Volunteer           NoProblem
# 1         5   OnCurb       1    3or4        Volunteer           NoProblem
# 2        26   OnCurb       2       0        Volunteer  StonesBranchLights
# 3        15   OnCurb       0       0  NYC Parks Staff           NoProblem
# 4        23   OnCurb       1       0        Volunteer              Stones
#
#            spc_common   nta                                    nta_name  \
# 0         English oak  QN45        Douglas Manor-Douglaston-Little Neck
# 1  crimson king maple  BX05                  Bedford Park-Fordham North
# 2         English oak  SI01  Annadale-Huguenot-Prince's Bay-Eltingville
# 3         honeylocust  SI11      Charleston-Richmond Valley-Tottenville
# 4    London planetree  MN03           Central Harlem North-Polo Grounds
#
#    borocode  boro_ct       boroname       zip_city  cb_num  st_senate  \
# 0         4  4152901         Queens    Little Neck     411         11
# 1         2  2039901          Bronx          Bronx     207         33
# 2         5  5017011  Staten Island  Staten Island     503         24
# 3         5  5024401  Staten Island  Staten Island     503         24
# 4         1  1022102      Manhattan       New York     110         30
#
#    st_assem  cncldist  year  month     month_sin     month_cos  spc_genus  \
# 0        25        23  2015      6  1.224647e-16 -1.000000e+00    Quercus
# 1        78        15  2016      9 -1.000000e+00 -1.836970e-16       Acer
# 2        62        51  2015      9 -1.000000e+00 -1.836970e-16    Quercus
# 3        62        51  2016      5  5.000000e-01 -8.660254e-01  Gleditsia
# 4        70         9  2016      6  1.224647e-16 -1.000000e+00   Platanus
#
#    onehot0  onehot1  onehot2  sidewalk-te0  sidewalk-te1  sidewalk-te2  \
# 0        0        1        0      0.182747      0.784939      0.035834
# 1        0        1        0      0.174502      0.790928      0.036055
# 2        0        0        1      0.172193      0.790928      0.035387
# 3        1        0        0      0.182320      0.779998      0.034896
# 4        0        1        0      0.171790      0.790994      0.034507
#
#    guards-te0  guards-te1  guards-te2
# 0    0.164804    0.800267    0.034977
# 1    0.205831    0.752257    0.038867
# 2    0.163806    0.799114    0.034915
# 3    0.163806    0.801522    0.034748
# 4    0.164804    0.800267    0.034708

# %%
print(len(encoded))
print(len(train_clean))
encoded_test.head()
# Out:
# 19984
# 19984
#    sidewalk-te2  guards-te2
# 0      0.034857    0.034866
# 1      0.034989    0.034866
# 2      0.034989    0.035278
# 3      0.034989    0.034866
# 4      0.034989    0.038081

# %%
train_clean.head()
# Out:
#    tree_dbh curb_loc  health steward   guards  sidewalk        user_type  \
# 0        14   OnCurb       1       0        0    Damage        Volunteer
# 1         5   OnCurb       1    3or4  Helpful  NoDamage        Volunteer
# 2        26   OnCurb       2       0        0  NoDamage        Volunteer
# 3        15   OnCurb       0       0        0    Damage  NYC Parks Staff
# 4        23   OnCurb       1       0        0  NoDamage        Volunteer
#
#              problems          spc_common  \
# 0           NoProblem         English oak
# 1           NoProblem  crimson king maple
# 2  StonesBranchLights         English oak
# 3           NoProblem         honeylocust
# 4              Stones    London planetree
#
#                                      nta_name  borocode  boro_ct  \
# 0        Douglas Manor-Douglaston-Little Neck         4  4152901
# 1                  Bedford Park-Fordham North         2  2039901
# 2  Annadale-Huguenot-Prince's Bay-Eltingville         5  5017011
# 3      Charleston-Richmond Valley-Tottenville         5  5024401
# 4           Central Harlem North-Polo Grounds         1  1022102
#
#         zip_city  cb_num  st_senate  st_assem  cncldist  year  month  \
# 0    Little Neck     411         11        25        23  2015      6
# 1          Bronx     207         33        78        15  2016      9
# 2  Staten Island     503         24        62        51  2015      9
# 3  Staten Island     503         24        62        51  2016      5
# 4       New York     110         30        70         9  2016      6
#
#       month_sin     month_cos  spc_genus  onehot0  onehot1  onehot2  \
# 0  1.224647e-16 -1.000000e+00    Quercus        0        1        0
# 1 -1.000000e+00 -1.836970e-16       Acer        0        1        0
# 2 -1.000000e+00 -1.836970e-16    Quercus        0        0        1
# 3  5.000000e-01 -8.660254e-01  Gleditsia        1        0        0
# 4  1.224647e-16 -1.000000e+00   Platanus        0        1        0
#
#     boroname-te1   boroname-te2 nta-te1 nta-te2  boroname-te0   nta-te0
# 0         Queens         Queens    QN45    QN45      0.178103  0.162867
# 1          Bronx          Bronx    BX05    BX05      0.175987  0.134456
# 2  Staten Island  Staten Island    SI01    SI01      0.174459  0.184069
# 3  Staten Island  Staten Island    SI11    SI11      0.174459  0.150957
# 4      Manhattan      Manhattan    MN03    MN03      0.173560  0.233289

# %%
train_clean.head()
# Out:
#    tree_dbh curb_loc  health steward   guards  sidewalk        user_type  \
# 0        14   OnCurb       1       0        0    Damage        Volunteer
# 1         5   OnCurb       1    3or4  Helpful  NoDamage        Volunteer
# 2        26   OnCurb       2       0        0  NoDamage        Volunteer
# 3        15   OnCurb       0       0        0    Damage  NYC Parks Staff
# 4        23   OnCurb       1       0        0  NoDamage        Volunteer
#
#              problems          spc_common  \
# 0           NoProblem         English oak
# 1           NoProblem  crimson king maple
# 2  StonesBranchLights         English oak
# 3           NoProblem         honeylocust
# 4              Stones    London planetree
#
#                                      nta_name  borocode  boro_ct  \
# 0        Douglas Manor-Douglaston-Little Neck         4  4152901
# 1                  Bedford Park-Fordham North         2  2039901
# 2  Annadale-Huguenot-Prince's Bay-Eltingville         5  5017011
# 3      Charleston-Richmond Valley-Tottenville         5  5024401
# 4           Central Harlem North-Polo Grounds         1  1022102
#
#         boroname       zip_city  cb_num  st_senate  st_assem  cncldist  year  \
# 0         Queens    Little Neck     411         11        25        23  2015
# 1          Bronx          Bronx     207         33        78        15  2016
# 2  Staten Island  Staten Island     503         24        62        51  2015
# 3  Staten Island  Staten Island     503         24        62        51  2016
# 4      Manhattan       New York     110         30        70         9  2016
#
#    month     month_sin     month_cos  spc_genus  onehot0  onehot1  onehot2  \
# 0      6  1.224647e-16 -1.000000e+00    Quercus        0        1        0
# 1      9 -1.000000e+00 -1.836970e-16       Acer        0        1        0
# 2      9 -1.000000e+00 -1.836970e-16    Quercus        0        0        1
# 3      5  5.000000e-01 -8.660254e-01  Gleditsia        1        0        0
# 4      6  1.224647e-16 -1.000000e+00   Platanus        0        1        0
#
#     nta-te0   nta-te1   nta-te2
# 0  0.162867  0.786526  0.058594
# 1  0.134456  0.785799  0.038320
# 2  0.184069  0.748023  0.033760
# 3  0.150957  0.804741  0.037280
# 4  0.233289  0.720040  0.034490

# %%
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
valid_scores = []
models = []

for fold, (train_idx, valid_idx) in enumerate(kf.split(train_clean_drop, y)):
    print(f'fold{fold} start')
    X_train, y_train = train_clean_drop.iloc[train_idx], y.iloc[train_idx]
    X_valid, y_valid = train_clean_drop.iloc[valid_idx], y.iloc[valid_idx]

    lgb_train = lgb.Dataset(X_train, y_train, weight=compute_sample_weight(class_weight='balanced', y=y_train).astype('float32'))
    lgb_eval = lgb.Dataset(X_valid, y_valid, weight=np.ones(len(X_valid)).astype('float32'))

    params = {
        'objective': 'multiclass',
        'metric': 'multi_logloss',
        'num_class': 3,
        'seed': 0
    }
    verbose_eval = -1 # この数字を1にすると学習時のスコア推移がコマンドライン表示される

    model = lgb.train(params,
                      lgb_train,
                      valid_sets=[lgb_train, lgb_eval],
                      num_boost_round=1000,
                       callbacks=[lgb.early_stopping(stopping_rounds=10, 
                                verbose=True), # early_stopping用コールバック関数
                           lgb.log_evaluation(verbose_eval)] # コマンドライン出力用コールバック関数))
                    )

    y_pred = model.predict(X_valid, num_iteration=model.best_iteration)
    y_pred_max = np.argmax(y_pred, axis=1)
    score = f1_score(y_valid, y_pred_max, average='macro')
    print(f'fold{fold} f1_score: {score:.4f}')
    valid_scores.append(score)
    models.append(model)
print(f'CV: {np.mean(valid_scores):.4f}')
# Out:
# fold0 start
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001947 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2468
# [LightGBM] [Info] Number of data points in the train set: 15987, number of used features: 31
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [407]	training's multi_logloss: 0.224635	valid_1's multi_logloss: 0.753399
# fold0 f1_score: 0.3318
# fold1 start
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007180 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2471
# [LightGBM] [Info] Number of data points in the train set: 15987, number of used features: 31
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [413]	training's multi_logloss: 0.217557	valid_1's multi_logloss: 0.75117
# fold1 f1_score: 0.3387
# fold2 start
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001715 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2465
# [LightGBM] [Info] Number of data points in the train set: 15987, number of used features: 31
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [440]	training's multi_logloss: 0.207196	valid_1's multi_logloss: 0.74387
# fold2 f1_score: 0.3574
# fold3 start
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001048 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2470
# [LightGBM] [Info] Number of data points in the train set: 15987, number of used features: 31
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [434]	training's multi_logloss: 0.205463	valid_1's multi_logloss: 0.759336
# fold3 f1_score: 0.3397
# fold4 start
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001270 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2461
# [LightGBM] [Info] Number of data points in the train set: 15988, number of used features: 31
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [423]	training's multi_logloss: 0.209087	valid_1's multi_logloss: 0.730113
# fold4 f1_score: 0.3648
# CV: 0.3465

# %%
y_pred = model.predict(test_clean_drop)
y_pred_max = np.argmax(y_pred, axis=1) # 最尤と判断したクラスの値にする
sample_df[1] = y_pred_max
# sample_df.to_csv('C:/python/signate/data/base2-sincos-genus-NoCategory-OneHotProblemFix.csv', header=None)

# %%
import pandas as pd

importance = model.feature_importance()
feature_names = model.feature_name()

df_importance = pd.DataFrame({'Feature': feature_names, 'Importance': importance})
df_importance
# Out:
#           Feature  Importance
# 0        tree_dbh        5179
# 1        curb_loc         252
# 2         steward         738
# 3          guards         671
# 4        sidewalk         790
# 5       user_type        1219
# 6        problems        1808
# 7      spc_common        3756
# 8             nta        3927
# 9        borocode         415
# 10        boro_ct        4712
# 11       zip_city        1516
# 12         cb_num        2145
# 13      st_senate        1692
# 14       st_assem        2429
# 15       cncldist        1984
# 16           year         500
# 17          month        1494
# 18      month_sin        1314
# 19      month_cos        1204
# 20      spc_genus        2761
# 21   BranchLights         268
# 22    BranchOther         154
# 23    MetalGrates          40
# 24      RootOther         175
# 25         Stones         372
# 26    TrunkLights          30
# 27     TrunkOther         200
# 28      WiresRope          98
# 29      NoProblem           0
# 30  problem_count         367
