# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import copy
import matplotlib.pyplot as plt

# pandasの行を省略しない
pd.set_option('display.max_columns', None)

# %%
categorical_columns = ['curb_loc', 'steward', 'guards',
       'sidewalk', 'user_type', 'problems', 'spc_common', 'spc_latin', 'nta',
       'nta_name', 'borocode', 'boro_ct', 'boroname', 'zip_city', 'cb_num',
       'st_senate', 'st_assem', 'cncldist']

# %%
train_df = pd.read_csv('C:/python/signate/data/train.csv')
test_df = pd.read_csv('C:/python/signate/data/test.csv')

train_df = train_df.drop(['Unnamed: 0'], axis=1)
test_df = test_df.drop(['Unnamed: 0'], axis=1)
train_df.head()
# Out:
#    created_at  tree_dbh curb_loc  health steward   guards  sidewalk  \
# 0  2015-06-29        14   OnCurb       1     NaN      NaN    Damage
# 1  2016-09-21         5   OnCurb       1    3or4  Helpful  NoDamage
# 2  2015-09-13        26   OnCurb       2     NaN      NaN  NoDamage
# 3  2016-05-09        15   OnCurb       0     NaN      NaN    Damage
# 4  2016-06-24        23   OnCurb       1     NaN      NaN  NoDamage
#
#          user_type            problems          spc_common  \
# 0        Volunteer                 NaN         English oak
# 1        Volunteer                 NaN  crimson king maple
# 2        Volunteer  StonesBranchLights         English oak
# 3  NYC Parks Staff                 NaN         honeylocust
# 4        Volunteer              Stones    London planetree
#
#                             spc_latin   nta  \
# 0                       Quercus robur  QN45
# 1     Acer platanoides 'Crimson King'  BX05
# 2                       Quercus robur  SI01
# 3  Gleditsia triacanthos var. inermis  SI11
# 4               Platanus x acerifolia  MN03
#
#                                      nta_name  borocode  boro_ct  \
# 0        Douglas Manor-Douglaston-Little Neck         4  4152901
# 1                  Bedford Park-Fordham North         2  2039901
# 2  Annadale-Huguenot-Prince's Bay-Eltingville         5  5017011
# 3      Charleston-Richmond Valley-Tottenville         5  5024401
# 4           Central Harlem North-Polo Grounds         1  1022102
#
#         boroname       zip_city  cb_num  st_senate  st_assem  cncldist
# 0         Queens    Little Neck     411         11        25        23
# 1          Bronx          Bronx     207         33        78        15
# 2  Staten Island  Staten Island     503         24        62        51
# 3  Staten Island  Staten Island     503         24        62        51
# 4      Manhattan       New York     110         30        70         9

# %% [markdown]
# データはほとんどカテゴリカル
# #### 思いついた精度向上案
# - commonを個別名称として、latinの上を属名として利用する
# - 地区が多すぎるので整理する

# %%
# train_dfのcolumnを取得
columns = test_df.columns

# %%
def cleansing(df):
    df['steward'] = df['steward'].replace({'None': 0, '1or2': 1, '3or4': 2, '4orMore': 3})
    return df

train_clean = cleansing(train_df)
test_clean = cleansing(test_df)

# %%
train_clean.head()
# Out:
#    created_at  tree_dbh curb_loc  health  steward   guards  sidewalk  \
# 0  2015-06-29        14   OnCurb       1      NaN      NaN    Damage
# 1  2016-09-21         5   OnCurb       1      2.0  Helpful  NoDamage
# 2  2015-09-13        26   OnCurb       2      NaN      NaN  NoDamage
# 3  2016-05-09        15   OnCurb       0      NaN      NaN    Damage
# 4  2016-06-24        23   OnCurb       1      NaN      NaN  NoDamage
#
#          user_type            problems          spc_common  \
# 0        Volunteer                 NaN         English oak
# 1        Volunteer                 NaN  crimson king maple
# 2        Volunteer  StonesBranchLights         English oak
# 3  NYC Parks Staff                 NaN         honeylocust
# 4        Volunteer              Stones    London planetree
#
#                             spc_latin   nta  \
# 0                       Quercus robur  QN45
# 1     Acer platanoides 'Crimson King'  BX05
# 2                       Quercus robur  SI01
# 3  Gleditsia triacanthos var. inermis  SI11
# 4               Platanus x acerifolia  MN03
#
#                                      nta_name  borocode  boro_ct  \
# 0        Douglas Manor-Douglaston-Little Neck         4  4152901
# 1                  Bedford Park-Fordham North         2  2039901
# 2  Annadale-Huguenot-Prince's Bay-Eltingville         5  5017011
# 3      Charleston-Richmond Valley-Tottenville         5  5024401
# 4           Central Harlem North-Polo Grounds         1  1022102
#
#         boroname       zip_city  cb_num  st_senate  st_assem  cncldist
# 0         Queens    Little Neck     411         11        25        23
# 1          Bronx          Bronx     207         33        78        15
# 2  Staten Island  Staten Island     503         24        62        51
# 3  Staten Island  Staten Island     503         24        62        51
# 4      Manhattan       New York     110         30        70         9

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score
# 一旦lightgbmで学習してみる
# label encodingでやってみる
y = train_df['health']
train_clean_drop = train_clean.drop(['health', 'created_at'], axis=1)
test_clean_drop = test_clean.drop(['created_at'], axis=1)

le = LabelEncoder()
for column in categorical_columns:
    train_clean_drop[column] = le.fit_transform(train_clean_drop[column])
    test_clean_drop[column] = le.fit_transform(test_clean_drop[column])

# カテゴリカル変数を指定
for col in categorical_columns:
    train_clean_drop[col] = train_clean_drop[col].astype('category')
    test_clean_drop[col] = test_clean_drop[col].astype('category')  

# trainとvalidに分割
X_train, X_test, y_train, y_test = train_test_split(train_clean_drop, y, test_size=0.2, random_state=1)
print(len(X_train))

# LightGBM用のデータセットに変換
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test)

# LightGBMのハイパーパラメータの設定
params = {
  'objective':'multiclass', # 目的 : 多クラス分類
  'metric':'multi_logloss', # 評価指標 : 不正解率(= 1-正解率)
  'num_class':3             # クラス数 : 3
}

verbose_eval = 1 # この数字を1にすると学習時のスコア推移がコマンドライン表示される

# LightGBMモデルの学習
model = lgb.train(params, train_data, num_boost_round=1000, 
                  valid_sets=[train_data, test_data],
                  callbacks=[lgb.early_stopping(stopping_rounds=10, 
                                verbose=True), # early_stopping用コールバック関数
                           lgb.log_evaluation(verbose_eval)] # コマンドライン出力用コールバック関数)
)
# テストデータでの予測
y_pred = model.predict(X_test)
y_pred_max = np.argmax(y_pred, axis=1) # 最尤と判断したクラスの値にする
# Calculate accuracy score
print("Accuracy:", f1_score(y_test, y_pred_max, average='macro'))
# Out:
# 15987
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003500 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1810
# [LightGBM] [Info] Number of data points in the train set: 15987, number of used features: 19
# [LightGBM] [Info] Start training from score -1.742156
# [LightGBM] [Info] Start training from score -0.236493
# [LightGBM] [Info] Start training from score -3.339172
# [1]	training's multi_logloss: 0.598875	valid_1's multi_logloss: 0.613999
# Training until validation scores don't improve for 90 rounds
# [2]	training's multi_logloss: 0.589093	valid_1's multi_logloss: 0.613566
# [3]	training's multi_logloss: 0.580621	valid_1's multi_logloss: 0.613413
# [4]	training's multi_logloss: 0.572447	valid_1's multi_logloss: 0.613305
# [5]	training's multi_logloss: 0.564963	valid_1's multi_logloss: 0.613994
# [6]	training's multi_logloss: 0.558254	valid_1's multi_logloss: 0.61495
# [7]	training's multi_logloss: 0.551529	valid_1's multi_logloss: 0.61591
# [8]	training's multi_logloss: 0.545691	valid_1's multi_logloss: 0.617306
# [9]	training's multi_logloss: 0.54005	valid_1's multi_logloss: 0.618462
# [10]	training's multi_logloss: 0.534563	valid_1's multi_logloss: 0.619799
# [11]	training's multi_logloss: 0.529309	valid_1's multi_logloss: 0.621343
# [12]	training's multi_logloss: 0.524802	valid_1's multi_logloss: 0.622982
# [13]	training's multi_logloss: 0.51953	valid_1's multi_logloss: 0.62433
# [14]	training's multi_logloss: 0.514435	valid_1's multi_logloss: 0.625584
# [15]	training's multi_logloss: 0.509848	valid_1's multi_logloss: 0.627401
# [16]	training's multi_logloss: 0.505335	valid_1's multi_logloss: 0.629013
# [17]	training's multi_logloss: 0.501758	valid_1's multi_logloss: 0.630244
# [18]	training's multi_logloss: 0.497518	valid_1's multi_logloss: 0.631371
# [19]	training's multi_logloss: 0.493779	valid_1's multi_logloss: 0.632319
# [20]	training's multi_logloss: 0.490028	valid_1's multi_logloss: 0.633336
# [21]	training's multi_logloss: 0.486152	valid_1's multi_logloss: 0.634586
# [22]	training's multi_logloss: 0.482608	valid_1's multi_logloss: 0.635785
# [23]	training's multi_logloss: 0.479178	valid_1's multi_logloss: 0.636599
# [24]	training's multi_logloss: 0.475294	valid_1's multi_logloss: 0.637928
# [25]	training's multi_logloss: 0.472095	valid_1's multi_logloss: 0.639033
# [26]	training's multi_logloss: 0.468811	valid_1's multi_logloss: 0.639978
# [27]	training's multi_logloss: 0.465156	valid_1's multi_logloss: 0.640565
# [28]	training's multi_logloss: 0.461917	valid_1's multi_logloss: 0.641646
# [29]	training's multi_logloss: 0.458625	valid_1's multi_logloss: 0.642731
# [30]	training's multi_logloss: 0.455535	valid_1's multi_logloss: 0.643584
# [31]	training's multi_logloss: 0.452303	valid_1's multi_logloss: 0.644921
# [32]	training's multi_logloss: 0.449707	valid_1's multi_logloss: 0.645322
# [33]	training's multi_logloss: 0.446998	valid_1's multi_logloss: 0.646425
# [34]	training's multi_logloss: 0.443801	valid_1's multi_logloss: 0.647286
# [35]	training's multi_logloss: 0.44059	valid_1's multi_logloss: 0.648348
# [36]	training's multi_logloss: 0.437831	valid_1's multi_logloss: 0.649224
# [37]	training's multi_logloss: 0.434785	valid_1's multi_logloss: 0.650201
# [38]	training's multi_logloss: 0.432039	valid_1's multi_logloss: 0.651485
# [39]	training's multi_logloss: 0.429667	valid_1's multi_logloss: 0.652225
# [40]	training's multi_logloss: 0.426979	valid_1's multi_logloss: 0.653081
# [41]	training's multi_logloss: 0.424058	valid_1's multi_logloss: 0.653983
# [42]	training's multi_logloss: 0.421819	valid_1's multi_logloss: 0.65488
# [43]	training's multi_logloss: 0.419463	valid_1's multi_logloss: 0.655817
# [44]	training's multi_logloss: 0.416425	valid_1's multi_logloss: 0.656793
# [45]	training's multi_logloss: 0.413488	valid_1's multi_logloss: 0.657644
# [46]	training's multi_logloss: 0.410861	valid_1's multi_logloss: 0.658667
# [47]	training's multi_logloss: 0.408865	valid_1's multi_logloss: 0.659144
# [48]	training's multi_logloss: 0.406758	valid_1's multi_logloss: 0.659959
# [49]	training's multi_logloss: 0.404294	valid_1's multi_logloss: 0.660881
# [50]	training's multi_logloss: 0.402054	valid_1's multi_logloss: 0.661687
# [51]	training's multi_logloss: 0.399753	valid_1's multi_logloss: 0.662059
# [52]	training's multi_logloss: 0.397778	valid_1's multi_logloss: 0.662599
# [53]	training's multi_logloss: 0.395707	valid_1's multi_logloss: 0.663211
# [54]	training's multi_logloss: 0.39316	valid_1's multi_logloss: 0.664109
# [55]	training's multi_logloss: 0.390817	valid_1's multi_logloss: 0.664932
# [56]	training's multi_logloss: 0.388674	valid_1's multi_logloss: 0.665579
# [57]	training's multi_logloss: 0.386778	valid_1's multi_logloss: 0.666452
# [58]	training's multi_logloss: 0.384578	valid_1's multi_logloss: 0.667354
# [59]	training's multi_logloss: 0.382474	valid_1's multi_logloss: 0.668287
# [60]	training's multi_logloss: 0.380239	valid_1's multi_logloss: 0.668848
# [61]	training's multi_logloss: 0.378405	valid_1's multi_logloss: 0.669413
# [62]	training's multi_logloss: 0.376825	valid_1's multi_logloss: 0.670033
# [63]	training's multi_logloss: 0.375142	valid_1's multi_logloss: 0.67081
# [64]	training's multi_logloss: 0.373197	valid_1's multi_logloss: 0.671461
# [65]	training's multi_logloss: 0.37147	valid_1's multi_logloss: 0.671989
# [66]	training's multi_logloss: 0.369838	valid_1's multi_logloss: 0.672643
# [67]	training's multi_logloss: 0.368059	valid_1's multi_logloss: 0.673482
# [68]	training's multi_logloss: 0.366283	valid_1's multi_logloss: 0.674245
# [69]	training's multi_logloss: 0.364542	valid_1's multi_logloss: 0.675026
# [70]	training's multi_logloss: 0.362684	valid_1's multi_logloss: 0.675631
# [71]	training's multi_logloss: 0.361009	valid_1's multi_logloss: 0.676149
# [72]	training's multi_logloss: 0.35969	valid_1's multi_logloss: 0.676875
# [73]	training's multi_logloss: 0.358374	valid_1's multi_logloss: 0.677443
# [74]	training's multi_logloss: 0.356639	valid_1's multi_logloss: 0.678017
# [75]	training's multi_logloss: 0.35488	valid_1's multi_logloss: 0.678644
# [76]	training's multi_logloss: 0.353478	valid_1's multi_logloss: 0.679236
# [77]	training's multi_logloss: 0.352004	valid_1's multi_logloss: 0.680009
# [78]	training's multi_logloss: 0.350192	valid_1's multi_logloss: 0.681015
# [79]	training's multi_logloss: 0.348748	valid_1's multi_logloss: 0.68155
# [80]	training's multi_logloss: 0.347605	valid_1's multi_logloss: 0.68196
# [81]	training's multi_logloss: 0.346379	valid_1's multi_logloss: 0.682224
# [82]	training's multi_logloss: 0.344563	valid_1's multi_logloss: 0.683329
# [83]	training's multi_logloss: 0.343326	valid_1's multi_logloss: 0.68396
# [84]	training's multi_logloss: 0.341642	valid_1's multi_logloss: 0.684696
# [85]	training's multi_logloss: 0.339812	valid_1's multi_logloss: 0.685615
# [86]	training's multi_logloss: 0.338386	valid_1's multi_logloss: 0.686187
# [87]	training's multi_logloss: 0.337188	valid_1's multi_logloss: 0.686824
# [88]	training's multi_logloss: 0.335824	valid_1's multi_logloss: 0.687388
# [89]	training's multi_logloss: 0.334424	valid_1's multi_logloss: 0.688154
# [90]	training's multi_logloss: 0.332999	valid_1's multi_logloss: 0.688585
# [91]	training's multi_logloss: 0.331799	valid_1's multi_logloss: 0.689
# [92]	training's multi_logloss: 0.330481	valid_1's multi_logloss: 0.689431
# [93]	training's multi_logloss: 0.329242	valid_1's multi_logloss: 0.689898
# [94]	training's multi_logloss: 0.327152	valid_1's multi_logloss: 0.691118
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 0.572447	valid_1's multi_logloss: 0.613305
# Accuracy: 0.2928357650579873

# %%
train_clean_drop.head()
# Out:
#    tree_dbh curb_loc steward guards sidewalk user_type problems spc_common  \
# 0        14        1       3      3        0         2       73         17
# 1         5        1       1      1        1         2       73         56
# 2        26        1       3      3        1         2       28         17
# 3        15        1       3      3        0         0       73         73
# 4        23        1       3      3        1         2       27         28
#
#   spc_latin  nta nta_name borocode boro_ct boroname zip_city cb_num st_senate  \
# 0        98  146       43        3    1082        3       23     52         1
# 1         7   52       11        1     297        0        4     18        23
# 2        98  169        1        4    1152        4       40     58        14
# 3        52  173       30        4    1174        4       40     58        14
# 4        81   87       28        0     113        2       27      9        20
#
#   st_assem cncldist
# 0        2       22
# 1       55       14
# 2       39       50
# 3       39       50
# 4       47        8

# %%
'''
# LightGBMモデルの学習
model = lgb.train(params, train_data,
                   num_boost_round=1000, valid_sets=[train_data, test_data], 
                    categorical_feature=categorical_columns, 
                    )

# テストデータでの予測
y_pred = model.predict(X_test)
y_pred_max = np.argmax(y_pred, axis=1)
# Calculate accuracy score
print("Accuracy:", f1_score(y_test, y_pred_max, average='macro'))
'''
